# %%
import pandas as pd
import requests
import os
from datetime import time, date
hode = {
    'Authorization': f'Bearer {os.environ["tokenCanvas"]}',
}
parametre = {'per_page': 100}

# %%
user_id = 19731
url = f"https://hvl.instructure.com/api/v1/courses/27432/users"
print(url)
respons = requests.get(url, headers=hode, params=parametre)
# Out:
# https://hvl.instructure.com/api/v1/courses/27432/users

# %%
respons.json()
# Out:
# [{'id': 1586,
#   'name': 'Kjersti Alsaker',
#   'created_at': '2017-12-16T00:21:38+01:00',
#   'sortable_name': 'Alsaker, Kjersti',
#   'short_name': 'Kjersti Alsaker',
#   'sis_user_id': 'fs:203:31674',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'kal@hvl.no',
#   'email': 'kjersti.alsaker@hvl.no'},
#  {'id': 67516,
#   'name': 'Kristine Amble',
#   'created_at': '2021-07-29T03:41:02+02:00',
#   'sortable_name': 'Amble, Kristine',
#   'short_name': 'Kristine Amble',
#   'sis_user_id': 'fs:203:26197',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '598235@hvl.no',
#   'email': '598235@stud.hvl.no'},
#  {'id': 66840,
#   'name': 'Merete Annie Andreassen',
#   'created_at': '2021-07-29T03:40:26+02:00',
#   'sortable_name': 'Andreassen, Merete Annie',
#   'short_name': 'Merete Annie Andreassen',
#   'sis_user_id': 'fs:203:202405',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597867@hvl.no',
#   'email': '597867@stud.hvl.no'},
#  {'id': 4397,
#   'name': 'Elisabeth Grov Beisland',
#   'created_at': '2018-03-15T13:21:11+01:00',
#   'sortable_name': 'Beisland, Elisabeth Grov',
#   'short_name': 'Elisabeth Grov Beisland',
#   'sis_user_id': 'fs:203:71341',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'ebei@hvl.no',
#   'email': 'elisabeth.grov.beisland@hvl.no'},
#  {'id': 69478,
#   'name': 'Odd Magne Bekkelund',
#   'created_at': '2021-07-29T03:43:05+02:00',
#   'sortable_name': 'Bekkelund, Odd Magne',
#   'short_name': 'Odd Magne Bekkelund',
#   'sis_user_id': 'fs:203:920666',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597112@hvl.no',
#   'email': '597112@stud.hvl.no'},
#  {'id': 107280,
#   'name': 'Merete Røineland Benestad',
#   'created_at': '2024-08-07T09:34:49+02:00',
#   'sortable_name': 'Benestad, Merete Røineland',
#   'short_name': 'Merete Røineland Benestad',
#   'sis_user_id': 'fs:203:146794',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'merb@hvl.no',
#   'email': 'merete.roineland.benestad@hvl.no'},
#  {'id': 30866,
#   'name': 'Kjersti Marie Blytt',
#   'created_at': '2019-07-01T03:10:13+02:00',
#   'sortable_name': 'Blytt, Kjersti Marie',
#   'short_name': 'Kjersti Marie Blytt',
#   'sis_user_id': 'fs:203:201892',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'kjebl@hvl.no',
#   'email': 'Kjersti.Marie.Blytt@hvl.no'},
#  {'id': 4494,
#   'name': 'Jeanne Helene Boge',
#   'created_at': '2018-03-15T13:22:44+01:00',
#   'sortable_name': 'Boge, Jeanne Helene',
#   'short_name': 'Jeanne Helene Boge',
#   'sis_user_id': 'fs:203:32231',
#   'integration_id': None,
#   'sis_import_id': 28845,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'jhb@hvl.no',
#   'email': 'jeanne.helene.boge@hvl.no'},
#  {'id': 5257,
#   'name': 'Yngvild Eline Brandser',
#   'created_at': '2018-03-21T13:14:23+01:00',
#   'sortable_name': 'Brandser, Yngvild Eline',
#   'short_name': 'Yngvild Eline Brandser',
#   'sis_user_id': 'fs:203:159613',
#   'integration_id': None,
#   'sis_import_id': 11211,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'yeb@hvl.no',
#   'email': 'Yngvild.Brandser.Alvsaker@hvl.no'},
#  {'id': 99605,
#   'name': 'Anders Brostrøm',
#   'created_at': '2024-01-12T14:33:52+01:00',
#   'sortable_name': 'Brostrøm, Anders',
#   'short_name': 'Anders Brostrøm',
#   'sis_user_id': 'hvl240112-p1-jbru',
#   'integration_id': None,
#   'sis_import_id': 23437,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'anders.brostrom@ju.se',
#   'email': 'anders.brostrom@ju.se'},
#  {'id': 66538,
#   'name': 'Berit Haugli Brujord',
#   'created_at': '2021-07-28T15:13:59+02:00',
#   'sortable_name': 'Brujord, Berit Haugli',
#   'short_name': 'Berit Haugli Brujord',
#   'sis_user_id': 'fs:203:352663',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '142659@hvl.no',
#   'email': '142659@stud.hvl.no'},
#  {'id': 99606,
#   'name': 'Emmanuel Chance',
#   'created_at': '2024-01-12T14:33:52+01:00',
#   'sortable_name': 'Chance, Emmanuel',
#   'short_name': 'Emmanuel Chance',
#   'sis_user_id': 'hvl240112-p2-jbru',
#   'integration_id': None,
#   'sis_import_id': 23437,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'emmanuel.Chance@vid.no',
#   'email': 'emmanuel.Chance@vid.no'},
#  {'id': 70140,
#   'name': 'Berit Kollen Dalholt',
#   'created_at': '2021-07-29T03:43:36+02:00',
#   'sortable_name': 'Dalholt, Berit Kollen',
#   'short_name': 'Berit Kollen Dalholt',
#   'sis_user_id': 'fs:203:940196',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '596630@hvl.no',
#   'email': '596630@stud.hvl.no'},
#  {'id': 4168,
#   'name': 'Leslie Sofia Pareja Eide',
#   'created_at': '2018-02-19T15:16:17+01:00',
#   'sortable_name': 'Eide, Leslie Sofia Pareja',
#   'short_name': 'Leslie Sofia Pareja Eide',
#   'sis_user_id': 'fs:203:95334',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'lpe@hvl.no',
#   'email': 'leslie.sofia.pareja.eide@hvl.no'},
#  {'id': 69808,
#   'name': 'Thea Rebecca Eigestad',
#   'created_at': '2021-07-29T03:43:21+02:00',
#   'sortable_name': 'Eigestad, Thea Rebecca',
#   'short_name': 'Thea Rebecca Eigestad',
#   'sis_user_id': 'fs:203:935534',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '598236@hvl.no',
#   'email': '598236@stud.hvl.no'},
#  {'id': 10876,
#   'name': 'Anja Eknes',
#   'created_at': '2018-03-27T17:11:36+02:00',
#   'sortable_name': 'Eknes, Anja',
#   'short_name': 'Anja Eknes',
#   'sis_user_id': 'fs:203:531626',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '181497@hvl.no',
#   'email': '181497@stud.hvl.no'},
#  {'id': 20654,
#   'name': 'Thea Røiseland Engelsen',
#   'created_at': '2018-08-04T03:12:44+02:00',
#   'sortable_name': 'Engelsen, Thea Røiseland',
#   'short_name': 'Thea Røiseland Engelsen',
#   'sis_user_id': 'fs:203:352857',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '577662@hvl.no',
#   'email': '577662@stud.hvl.no'},
#  {'id': 90120,
#   'name': 'Agathe Krekvik Govertsen',
#   'created_at': '2023-07-29T03:41:58+02:00',
#   'sortable_name': 'Govertsen, Agathe Krekvik',
#   'short_name': 'Agathe Krekvik Govertsen',
#   'sis_user_id': 'fs:203:157894',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '117593@hvl.no',
#   'email': '117593@stud.hvl.no'},
#  {'id': 27858,
#   'name': 'Gerd Gran',
#   'created_at': '2018-12-18T13:11:42+01:00',
#   'sortable_name': 'Gran, Gerd',
#   'short_name': 'Gerd Gran',
#   'sis_user_id': 'fs:203:174423',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'ggra@hvl.no',
#   'email': 'gerd.gran@hvl.no'},
#  {'id': 67538,
#   'name': 'Sigurd Myhre Halvorsen',
#   'created_at': '2021-07-29T03:41:03+02:00',
#   'sortable_name': 'Halvorsen, Sigurd Myhre',
#   'short_name': 'Sigurd Myhre Halvorsen',
#   'sis_user_id': 'fs:203:262498',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '598233@hvl.no',
#   'email': '598233@stud.hvl.no'},
#  {'id': 67639,
#   'name': 'Tina Angelica Hannisdal',
#   'created_at': '2021-07-29T03:41:09+02:00',
#   'sortable_name': 'Hannisdal, Tina Angelica',
#   'short_name': 'Tina Angelica Hannisdal',
#   'sis_user_id': 'fs:203:491144',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597899@hvl.no',
#   'email': '597899@stud.hvl.no'},
#  {'id': 27946,
#   'name': 'Kurt Hatløy',
#   'created_at': '2018-12-20T02:10:37+01:00',
#   'sortable_name': 'Hatløy, Kurt',
#   'short_name': 'Kurt Hatløy',
#   'sis_user_id': 'fs:203:125329',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '582401@hvl.no',
#   'email': '582401@stud.hvl.no'},
#  {'id': 27952,
#   'name': 'Kristine Farestveit Helland',
#   'created_at': '2018-12-20T02:10:50+01:00',
#   'sortable_name': 'Helland, Kristine Farestveit',
#   'short_name': 'Kristine Farestveit Helland',
#   'sis_user_id': 'fs:203:141967',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '144537@hvl.no',
#   'email': '144537@stud.hvl.no'},
#  {'id': 67597,
#   'name': 'Ida Pedersen Holmedal',
#   'created_at': '2021-07-29T03:41:07+02:00',
#   'sortable_name': 'Holmedal, Ida Pedersen',
#   'short_name': 'Ida Pedersen Holmedal',
#   'sis_user_id': 'fs:203:489461',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '598237@hvl.no',
#   'email': '598237@stud.hvl.no'},
#  {'id': 53839,
#   'name': 'Marianne Giske Holvik',
#   'created_at': '2020-09-04T18:12:24+02:00',
#   'sortable_name': 'Holvik, Marianne Giske',
#   'short_name': 'Marianne Giske Holvik',
#   'sis_user_id': 'fs:203:147985',
#   'integration_id': None,
#   'sis_import_id': 28382,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'magho@hvl.no',
#   'email': 'marianne.giske.holvik@hvl.no'},
#  {'id': 27861,
#   'name': 'Åse Humberset',
#   'created_at': '2018-12-18T13:11:46+01:00',
#   'sortable_name': 'Humberset, Åse',
#   'short_name': 'Åse Humberset',
#   'sis_user_id': 'fs:203:4380',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'ahum@hvl.no',
#   'email': 'ase.humberset@hvl.no'},
#  {'id': 69363,
#   'name': 'Katrine Langemyr Larsen',
#   'created_at': '2021-07-29T03:43:00+02:00',
#   'sortable_name': 'Larsen, Katrine Langemyr',
#   'short_name': 'Katrine Langemyr Larsen',
#   'sis_user_id': 'fs:203:907507',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '598241@hvl.no',
#   'email': '598241@stud.hvl.no'},
#  {'id': 28744,
#   'name': 'Anne Torine Litherland',
#   'created_at': '2019-01-08T11:11:58+01:00',
#   'sortable_name': 'Litherland, Anne Torine',
#   'short_name': 'Anne Torine Litherland',
#   'sis_user_id': 'fs:203:76209',
#   'integration_id': None},
#  {'id': 67522,
#   'name': 'Camilla Løvall',
#   'created_at': '2021-07-29T03:41:02+02:00',
#   'sortable_name': 'Løvall, Camilla',
#   'short_name': 'Camilla Løvall',
#   'sis_user_id': 'fs:203:262057',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'calo@hvl.no',
#   'email': 'camilla.lovall@hvl.no'},
#  {'id': 27860,
#   'name': 'Heidi Øksnes Markussen',
#   'created_at': '2018-12-18T13:11:45+01:00',
#   'sortable_name': 'Markussen, Heidi Øksnes',
#   'short_name': 'Heidi Øksnes Markussen',
#   'sis_user_id': 'fs:203:37170',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'hom@hvl.no',
#   'email': 'heidi.oksnes.markussen@hvl.no'},
#  {'id': 67287,
#   'name': 'Lotte Miriam Eri Mjelde',
#   'created_at': '2021-07-29T03:40:49+02:00',
#   'sortable_name': 'Mjelde, Lotte Miriam Eri',
#   'short_name': 'Lotte Miriam Eri Mjelde',
#   'sis_user_id': 'fs:203:340758',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'lmem@hvl.no',
#   'email': 'lmem@hvl.no'},
#  {'id': 24466,
#   'name': 'Michael André Helnes Mortensen',
#   'created_at': '2018-08-15T18:13:27+02:00',
#   'sortable_name': 'Mortensen, Michael André Helnes',
#   'short_name': 'Michael André Helnes Mortensen',
#   'sis_user_id': 'fs:203:523734',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'miahm@hvl.no',
#   'email': 'michael.andre.helnes.mortensen@hvl.no'},
#  {'id': 67468,
#   'name': 'Kristina Hjelmeland Njøsen',
#   'created_at': '2021-07-29T03:40:59+02:00',
#   'sortable_name': 'Njøsen, Kristina Hjelmeland',
#   'short_name': 'Kristina Hjelmeland Njøsen',
#   'sis_user_id': 'fs:203:358158',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597896@hvl.no',
#   'email': '597896@stud.hvl.no'},
#  {'id': 27859,
#   'name': 'Torill Elin Olsen',
#   'created_at': '2018-12-18T13:11:43+01:00',
#   'sortable_name': 'Olsen, Torill Elin',
#   'short_name': 'Torill Elin Olsen',
#   'sis_user_id': 'fs:203:36098',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'tol@hvl.no',
#   'email': 'torill.elin.olsen@hvl.no'},
#  {'id': 90326,
#   'name': 'Hege Kristin Raudstein',
#   'created_at': '2023-07-29T03:42:15+02:00',
#   'sortable_name': 'Raudstein, Hege Kristin',
#   'short_name': 'Hege Kristin Raudstein',
#   'sis_user_id': 'fs:203:174643',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '100128@hvl.no',
#   'email': '100128@stud.hvl.no'},
#  {'id': 4554,
#   'name': 'Marit Hegg Reime',
#   'created_at': '2018-03-15T13:23:43+01:00',
#   'sortable_name': 'Reime, Marit Hegg',
#   'short_name': 'Marit Hegg Reime',
#   'sis_user_id': 'fs:203:33955',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'mhr@hvl.no',
#   'email': 'marit.hegg.reime@hvl.no'},
#  {'id': 66504,
#   'name': 'Henriette Nilsen Rysjedal',
#   'created_at': '2021-07-28T15:13:58+02:00',
#   'sortable_name': 'Rysjedal, Henriette Nilsen',
#   'short_name': 'Henriette Nilsen Rysjedal',
#   'sis_user_id': 'fs:203:360263',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '137281@hvl.no',
#   'email': '137281@stud.hvl.no'},
#  {'id': 66353,
#   'name': 'Linn Elin Rødal',
#   'created_at': '2021-07-28T15:13:31+02:00',
#   'sortable_name': 'Rødal, Linn Elin',
#   'short_name': 'Linn Elin Rødal',
#   'sis_user_id': 'fs:203:101274',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '096570@hvl.no',
#   'email': '096570@stud.hvl.no'},
#  {'id': 67160,
#   'name': 'Åse Margrete Sagen',
#   'created_at': '2021-07-29T03:40:43+02:00',
#   'sortable_name': 'Sagen, Åse Margrete',
#   'short_name': 'Åse Margrete Sagen',
#   'sis_user_id': 'fs:203:22690',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597873@hvl.no',
#   'email': '597873@stud.hvl.no'},
#  {'id': 69745,
#   'name': 'Lars Martin Sandbakken',
#   'created_at': '2021-07-29T03:43:18+02:00',
#   'sortable_name': 'Sandbakken, Lars Martin',
#   'short_name': 'Lars Martin Sandbakken',
#   'sis_user_id': 'fs:203:931272',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597838@hvl.no',
#   'email': '597838@stud.hvl.no'},
#  {'id': 66945,
#   'name': 'Ingun Børve Skjelbreid',
#   'created_at': '2021-07-29T03:40:32+02:00',
#   'sortable_name': 'Skjelbreid, Ingun Børve',
#   'short_name': 'Ingun Børve Skjelbreid',
#   'sis_user_id': 'fs:203:288730',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '240087@hvl.no',
#   'email': '240087@stud.hvl.no'},
#  {'id': 70439,
#   'name': 'Hege Ingrid Sydnes',
#   'created_at': '2021-07-29T03:43:48+02:00',
#   'sortable_name': 'Sydnes, Hege Ingrid',
#   'short_name': 'Hege Ingrid Sydnes',
#   'sis_user_id': 'fs:203:942087',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597877@hvl.no',
#   'email': '597877@stud.hvl.no'},
#  {'id': 67108,
#   'name': 'Nanda Kristin Sæterøy-Hansen',
#   'created_at': '2021-07-29T03:40:40+02:00',
#   'sortable_name': 'Sæterøy-Hansen, Nanda Kristin',
#   'short_name': 'Nanda Kristin Sæterøy-Hansen',
#   'sis_user_id': 'fs:203:224129',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '598232@hvl.no',
#   'email': '598232@stud.hvl.no'},
#  {'id': 15778,
#   'name': 'Tonje Teigland',
#   'created_at': '2018-07-17T11:11:37+02:00',
#   'sortable_name': 'Teigland, Tonje',
#   'short_name': 'Tonje Teigland',
#   'sis_user_id': 'fs:203:85390',
#   'integration_id': None,
#   'sis_import_id': 17233,
#   'root_account': 'hvl.instructure.com',
#   'login_id': 'tote@hvl.no',
#   'email': 'tonje.teigland@hvl.no'},
#  {'id': 67168,
#   'name': 'Stine Lund Tørresvold',
#   'created_at': '2021-07-29T03:40:43+02:00',
#   'sortable_name': 'Tørresvold, Stine Lund',
#   'short_name': 'Stine Lund Tørresvold',
#   'sis_user_id': 'fs:203:323655',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597888@hvl.no',
#   'email': '597888@stud.hvl.no'},
#  {'id': 70483,
#   'name': 'Marte Langberg Vangen',
#   'created_at': '2021-07-29T03:43:51+02:00',
#   'sortable_name': 'Vangen, Marte Langberg',
#   'short_name': 'Marte Langberg Vangen',
#   'sis_user_id': 'fs:203:942559',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '598231@hvl.no',
#   'email': '598231@stud.hvl.no'},
#  {'id': 69864,
#   'name': 'Tori Nedregård Økdal',
#   'created_at': '2021-07-29T03:43:23+02:00',
#   'sortable_name': 'Økdal, Tori Nedregård',
#   'short_name': 'Tori Nedregård Økdal',
#   'sis_user_id': 'fs:203:936877',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597844@hvl.no',
#   'email': '597844@stud.hvl.no'},
#  {'id': 69997,
#   'name': 'Elise Arner Ådnanes',
#   'created_at': '2021-07-29T03:43:29+02:00',
#   'sortable_name': 'Ådnanes, Elise Arner',
#   'short_name': 'Elise Arner Ådnanes',
#   'sis_user_id': 'fs:203:938827',
#   'integration_id': None,
#   'sis_import_id': 29522,
#   'root_account': 'hvl.instructure.com',
#   'login_id': '597840@hvl.no',
#   'email': '597840@stud.hvl.no'}]
