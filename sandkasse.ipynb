# %%
import pandas as pd
data = pd.read_csv('enrollments.csv')
# Out:
# C:\Users\AKV\AppData\Local\Temp\ipykernel_6968\4003027241.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('enrollments.csv')

# %%
student = "1337689"
data[data['user_id'] == "fs:203:"+student]
# Out:
# Empty DataFrame
# Columns: [course_id, user_id, role, section_id, status, associated_user_id]
# Index: []
