# %%
import pandas as pd
data = pd.read_csv("web_logs-202412041409-0.txt")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194562 entries, 0 to 1194561
# Data columns (total 25 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   key.id                              1194562 non-null  object
#  1   value.timestamp                     1194562 non-null  object
#  2   value.user_id                       934743 non-null   float64
#  3   value.real_user_id                  1343 non-null     float64
#  4   value.course_id                     640480 non-null   float64
#  5   value.quiz_id                       10486 non-null    float64
#  6   value.discussion_id                 6887 non-null     float64
#  7   value.conversation_id               2081 non-null     float64
#  8   value.assignment_id                 7298 non-null     float64
#  9   value.url                           1194562 non-null  object
# ...

# %%
uttrekk = data[['value.url', 'value.course_id', 'value.web_application_controller', 'value.web_application_action', 'value.web_application_context_type']]

# %%
uttrekk.head(20)
# Out:
#                                             value.url  value.course_id  \
# 0                              /courses/30080/modules          30080.0
# 1   /api/v1/courses/29417/pages/fredag-13-septembe...          29417.0
# 2                                        /api/graphql              NaN
# 3         /api/v1/courses/29605?query_string_redacted          29605.0
# 4                  /api/v1/release_notes/unread_count              NaN
# 5                 /courses/30080/modules/progressions          30080.0
# 6                    /api/v1/accounts/1/courses/30384          30384.0
# 7       /api/v1/courses/25714/activity_stream/summary          25714.0
# 8                     /api/v1/accounts/1/courses/4938           4938.0
# 9         /api/v1/courses/28882?query_string_redacted          28882.0
# 10  /api/v1/canvadoc_session?blob=%7B%22user_id%22...              NaN
# 11  /api/v1/courses/29248/pages/4-problems-and-sol...          29248.0
# ...

# %%
uttrekk['value.web_application_action'].value_counts()
# Out:
# value.web_application_action
# index                    190707
# item_sequence            163921
# show                     140886
# show_revision             93219
# unread_count              52093
#                           ...
# members                       1
# grades                        1
# group_index                   1
# revisions                     1
# course_accounts_index         1
# Name: count, Length: 200, dtype: int64

# %%
uttrekk['value.web_application_controller'].value_counts()
# Out:
# value.web_application_controller
# context_module_items_api    225170
# courses                     166281
# files                       149252
# wiki_pages_api               97401
# users                        67133
#                              ...
# page_comments                    1
# lti/membership_service           1
# content_exports_api              1
# rubrics                          1
# sub_accounts_api                 1
# Name: count, Length: 121, dtype: int64

# %%
uttrekk['value.web_application_context_type'].value_counts()
# Out:
# value.web_application_context_type
# Course                     640476
# User                        33860
# Account                     20711
# UserProfile                  3745
# Group                        1541
# CourseSection                 573
# Quizzes::QuizSubmission        38
# AssessmentQuestion             14
# Assignment                      2
# Name: count, dtype: int64

# %%
uttrekk['value.web_application_context_id'].value_counts()
# Out:
# value.web_application_context_id
# 30742.0    80793
# 29207.0    35480
# 12436.0    33828
# 28924.0    23168
# 1.0        19372
#            ...
# 69959.0        1
# 67093.0        1
# 31545.0        1
# 47955.0        1
# 68417.0        1
# Name: count, Length: 15032, dtype: int64
