# %%
import requests
import os
import pandas as pd
tokenCanvas = os.environ['tokenCanvas']

headers = {
    'Authorization': f'Bearer {tokenCanvas}',
}
params = {
    'per_page': 100,
}

# %% [markdown]
# # Frå "Observer" til "Gjest"
# Det går an å endre alle eksisterande, men det er lite vits i.

# %%
data = pd.read_csv("provisioning_csv_21_May_2025_6124920250521-4066277-gamn8g.csv")
observer = data[data['role_id']==7]
utan_user_id = observer[observer['user_id'].isna()]
aktuelle = observer.dropna(subset=['user_id'])
# Out:
# C:\Users\AKV\AppData\Local\Temp\ipykernel_11844\1018776857.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("provisioning_csv_21_May_2025_6124920250521-4066277-gamn8g.csv")

# %%
aktuelle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56661 entries, 2041 to 471934
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   canvas_course_id           56661 non-null  int64
#  1   course_id                  56517 non-null  object
#  2   canvas_user_id             56661 non-null  int64
#  3   user_id                    56661 non-null  object
#  4   role                       56661 non-null  object
#  5   role_id                    56661 non-null  int64
#  6   canvas_section_id          56661 non-null  int64
#  7   section_id                 53375 non-null  object
#  8   status                     56661 non-null  object
#  9   canvas_associated_user_id  2 non-null      float64
#  10  associated_user_id         2 non-null      object
#  11  created_by_sis             56661 non-null  bool
#  12  base_role_type             56661 non-null  object
# ...

# %%
section_id = aktuelle.dropna(subset=['section_id'])
course_id = aktuelle.dropna(subset=['course_id'])

# %%
section_id
# Out:
#         canvas_course_id                    course_id  canvas_user_id  \
# 3441                 257                ST_0203000000            1345
# 3442                 257                ST_0203000000            1344
# 3443                 257                ST_0203000000            1343
# 3444                 257                ST_0203000000            1341
# 3445                 257                ST_0203000000            1340
# ...                  ...                          ...             ...
# 471930             28875   UE_203_DAT102_1_2025_VÅR_1           93231
# 471931             28875   UE_203_DAT102_1_2025_VÅR_1           93970
# 471932             28875   UE_203_DAT102_1_2025_VÅR_1           94049
# 471933             28875   UE_203_DAT102_1_2025_VÅR_1           94142
# 471934             28870  UE_203_DAT100_1_2024_HØST_1           94425
#
#                user_id      role  role_id  canvas_section_id  \
# 3441     fs:203:560201  observer        7                291
# ...

# %%
test = section_id[section_id['course_id']=="ST_0203000000"]

# %%
test[['course_id', 'user_id']]
# Out:
#             course_id         user_id
# 3441    ST_0203000000   fs:203:560201
# 3442    ST_0203000000   fs:203:531787
# 3443    ST_0203000000   fs:203:531782
# 3444    ST_0203000000   fs:203:324177
# 3445    ST_0203000000    fs:203:32123
# ...               ...             ...
# 470630  ST_0203000000   fs:203:638960
# 470631  ST_0203000000  fs:203:1344157
# 470632  ST_0203000000  fs:203:1341075
# 470633  ST_0203000000  fs:203:1327729
# 471030  ST_0203000000  fs:203:1342946
#
# [18618 rows x 2 columns]
